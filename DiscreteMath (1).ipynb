# %%
print("Place your order:")
o = input()
if o == 'cheese burger deluxe' or 'Cheese Burger Deluxe':
    print(o + " add fries and drinks")
elif o != 'cheese burger deluxe' or 'Cheese Burger Deluxe':
    print(o + " add sundae")
else:
    print(" ")
# Out:
# Place your order:
#  g
# g add fries and drinks
